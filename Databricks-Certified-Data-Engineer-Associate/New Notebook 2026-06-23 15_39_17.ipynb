# %%
# %sql
select * from json.`/Volumes/formula1/landing/files/constructors.json`

# %%
# %sql
SELECT *,
       _metadata.file_path AS source_file
FROM json.`/Volumes/formula1/landing/files/constructors.json`;

# %%
# %sql
select current_metastore()

# %%
# %fs ls /Volumes/gizmobox/landing/operational_data/customers/

# %%
# %sql
SELECT *,
       _metadata.file_path AS source_file
FROM json.`dbfs:/Volumes/gizmobox/landing/operational_data/customers/customers_2024_10.json`;

# %%
# %sql
select * from binaryFile.`/Volumes/gizmobox/landing/operational_data/memberships/*/*.png`

# %%
# %sql
select
  *
from
  read_files(
    '/Volumes/gizmobox/landing/operational_data/addresses/',
    format =>  'csv',
    delimiter => '\t',
    header => true
  )
# Out:
# Databricks data profile. Run in Databricks to view.

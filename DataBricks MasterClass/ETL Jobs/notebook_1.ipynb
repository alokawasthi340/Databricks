# %%
# %sql
create volume if not exists databrickscatalog.bronze.job_vol

# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load("/Volumes/databrickscatalog/bronze/bronze_volume/stores/")

# %%
df.write.format("delta").mode("overwrite").save("/Volumes/databrickscatalog/bronze/job_vol/raw/stores/")

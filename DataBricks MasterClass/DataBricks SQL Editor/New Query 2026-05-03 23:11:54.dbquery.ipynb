-- %%
-- select * from databrickscatalog.sliver.customers_sliver;

-- select * from databrickscatalog.sliver.products_sliver
-- where category=:para_category;
-- when you want to create a paramter(:parameter_name)
select identifier(:para_category) from databrickscatalog.sliver.products_sliver

-- when you want to create a column name witindetifier(:parameter_name),indetifier(:parameter_name2)

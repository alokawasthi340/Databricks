# %% [markdown]
# ## Volumes

# %%
# %sql
CREATE VOLUME IF NOT EXISTS databrickscatalog.bronze.bronze_volume

# %%
# %sql
select * from csv.`/Volumes/databrickscatalog/bronze/bronze_volume/sales`

# %%
dbutils.help()

# %%
# dbutils.fs.ls("/Volumes/databrickscatalog/bronze/bronze_volume/sales/")
dbutils.fs.mkdirs("/Volumes/databrickscatalog/bronze/bronze_volume/customer")

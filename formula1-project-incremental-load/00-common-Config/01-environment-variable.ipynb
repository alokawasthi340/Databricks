# %%
# setting the env variable for unity catalog
catalog_name='formula1_incr'
bronze_schema='bronze'
silver_schema='silver'
gold_schema='gold'
control_schema='control'
landing_path='/Volumes/formula1_incr/landing/files'
